# %% [markdown]
# # Unique label count
#
# Read the labeled CSV and compute the number of unique labels.

# %%
import pandas as pd

csv_path = r"C:\\Users\\anoureldin\\Desktop\\TSP\\semi-supervised-labeling-framework\\results\\llm\\labeled_CSA_CAIQ.csv"
df = pd.read_csv(csv_path)

labels_series = df["labels"].dropna().astype(str)
labels = labels_series.str.split(",").explode().str.strip()
unique_labels = sorted({label for label in labels if label})

print(f"Unique labels: {len(unique_labels)}")
# Optional: show a small sample
print(unique_labels[:20])
# Out:
# Unique labels: 1065
# ['API communications', 'Acceptable risk', 'Acceptable use', 'Acceptance criteria', 'Access accountability', 'Access authorization', 'Access change communication', 'Access change recording', 'Access control', 'Access control procedure', 'Access control system', 'Access deprovisioning', 'Access disclosure', 'Access governance', 'Access granting', 'Access implementation', 'Access levels', 'Access management', 'Access management procedures', 'Access modification']
