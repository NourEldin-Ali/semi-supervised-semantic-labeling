# %% [markdown]
# # Unique label count
#
# Read the labeled CSV and compute the number of unique labels.

# %%
import pandas as pd

csv_path = r"C:\\Users\\anoureldin\\Downloads\\results\\labeled_iso_27701.csv"
df = pd.read_csv(csv_path)

labels_series = df["labels"].dropna().astype(str)
labels = labels_series.str.split(",").explode().str.strip()
unique_labels = sorted({label for label in labels if label})

print(f"Unique labels: {len(unique_labels)}")
# Optional: show a small sample
print(unique_labels[:20])
# Out:
# Unique labels: 508
# ['Access attempts', 'Access controls', 'Access logging', 'Access monitoring', 'Access review frequency', 'Accuracy', 'Accuracy checks', 'Accuracy procedures', 'Alignment assessment', 'Alternative processing locations', 'Anonymization techniques', 'Appropriate safeguards', 'Approval process', 'Archive deletion', 'Audit evidence', 'Audit log review', 'Audit logs', 'Audit purposes', 'Auditability', 'Auditor training']
